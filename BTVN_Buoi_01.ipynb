# %%
#Câu 1:
#Python có thể  được dùng trong các lĩnh vực : Phát triển Web, Khoa học dữ liệu, AI , Machine learning, Tự động hóa
# Phát triển phần mềm ,..... Python là ngôn ngữ mạnh mẽ có thể sử dụng trong hầu hết các lĩnh vực .

# %%
#Câu 2:
#So sánh đặc điểm của C++ và Python:
#C++:
# - Cần khai báo kiểu dữ liệu khi khi khai báo biến
# - Cần ngoặc nhọn để có thể chạy được
# - Cấu trúc code phức tạp hơn
#Python:
# - Khai báo biến không cần kiểu dữ liệu
# - Không cần ngoặc nhọn

# %%
#Câu 3:
#Python là ngôn ngữ thông dịch. Vì
#Khi bạn chạy một chương trình Python, mã nguồn Python (.py) sẽ không được biên dịch trực tiếp thành mã máy (machine code) như C++ hay Java.
#Thay vào đó, Python sử dụng một trình thông dịch (interpreter) để thực thi mã nguồn trực tiếp, dòng theo dòng.

# %%
#Câu 5:
#Cách khai báo biến :
a=9;
name="Nguyen Phuc Xuan"
b=3;
#Các toán tử :
# * Toán Tử Số Học : +, -, *, /, %, **, // .
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a**b)
print(a//b)
# * Toán tử quan hệ : ==, >= , <= , >, < , != .
print(a==b)
print(a>=b)
print(a<=b)
print(a<b)
print(a>b)
print(a!=b)
# * Toán tử gán : = , +=, -=, *=, /=, %= , **=, //= .
a=10
a += 1
a -= 1
a *= 1
a /= 1
a %= 1
a **=1
a //=1
# * Toán tử logic : and , or , not .
print(True and True)
print(False or True)
print(not False)
# * Toán tử biwter : &, |, ^, ~, >> , <<
#print(a & b)
#print(a | b)
#print(~a)
#print(a^b)
#print(a>>a)
#print(a<<a)
# * Toán tử khai thác : in , not in .
c= [3,4,5,6,7]
d=7
print(d in c)
print(d not in c)
# * Toán tử xác thực :
print(a is b)
print(a is not b)
#Các kiểu dữ liệu trong Python:
#str
x = str("Hello")
#int
x= int(5)
#float
x = float(5.5)
#complex
x= complex(1j)
#list
x = list(("â","b","c"))
#tuple
x = tuple(("a","b","c"))
#range
x = range(6)
#dict
x = dict(name="Xuan",age=19)
#set
x = set(("a","b","c"))
#frozenset
a = frozenset(("a","b","c"))
#bool
a = bool(5)
#bytes
a = bytes(5)
#bytearray
a = bytearray(5)
#memoryview
a = memoryview(bytes(5))
